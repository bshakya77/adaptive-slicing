# %%
#Import required functions and classes
from sahi import AutoDetectionModel
from sahi.utils.cv import read_image, read_image_as_pil
from sahi.utils.file import Path, increment_path, list_files, save_json, save_pickle, download_from_url
from sahi.predict import get_prediction, get_sliced_prediction, predict, agg_prediction, predict 
from sahi.prediction import visualize_object_predictions
from sahi.postprocess.utils import ObjectPredictionList, has_match, merge_object_prediction_pair
from IPython.display import Image
from numpy import asarray
import cv2
import os
import time
from PIL import Image
import json
import numpy as np
from tqdm import tqdm
import time
from sahi.prediction import ObjectPrediction, PredictionResult
from pathlib import Path
from multiprocessing import Pool, cpu_count
import torch
from torchvision.ops import nms, clip_boxes_to_image

# %%
yolov8_model_path = '../models/yolov8/last.pt'

# %%
detection_model = AutoDetectionModel.from_pretrained(
    model_type='ultralytics',
    model_path=yolov8_model_path,
    confidence_threshold=0.3,
    device="cuda:0", # or 'cpu'
)

# %%
def get_slice_parameters(object_density, slice_size):
    
    if object_density >= 50:
        #slice_size = min_dim // 4
        slice_width = slice_size
        slice_height = slice_size
        overlap_width_ratio = 0.5
        overlap_height_ratio = 0.5
    elif 25 <= object_density < 50:
        #slice_size = min_dim // 2
        slice_width = slice_size
        slice_height = slice_size
        overlap_width_ratio = 0.25
        overlap_height_ratio = 0.25
    elif 10 <= object_density < 25:
        #slice_size = min_dim // 2
        slice_width = slice_size
        slice_height = slice_size
        overlap_width_ratio = 0.15
        overlap_height_ratio = 0.15
    else:
        return

    return slice_width, slice_height, overlap_width_ratio, overlap_height_ratio

# %%
def merged_preds_to_coco(preds, image_id):
    coco_predictions = []
    for pred in preds:
        try:
            coco = pred.to_coco_prediction(image_id=image_id)
            coco_dict = {
                "image_id": coco.image_id,
                "bbox": coco.bbox,
                "score": coco.score,
                "category_id": coco.category_id,
                "segmentation": coco.segmentation,
                "iscrowd": coco.iscrowd,
                "area": coco.area,
            }
            # Optionally include category_name (not used in COCO eval)
            # coco_dict["category_name"] = coco.category_name

            # Only add if bbox is valid (non-empty)
            if coco_dict["bbox"]:
                coco_predictions.append(coco_dict)
        except Exception as e:
            print(f"Failed to convert to COCO dict: {e}")
    return coco_predictions

# %%
def nms_merge(predictions, iou_threshold=0.5):
    if not predictions:
        return []
    boxes = torch.tensor([p.bbox.to_xyxy() for p in predictions])
    scores = torch.tensor([p.score.value for p in predictions])
    keep_indices = nms(boxes, scores, iou_threshold).tolist()
    return [predictions[i] for i in keep_indices]

# %%
# Apply Non-Maximum Suppression (NMS)
def apply_nms(detections, iou_threshold=0.5):
    boxes, scores, labels = [], [], []
    for det in detections:
        boxes.append(det['box'])
        scores.append(det['confidence'])
        labels.append(det['class_id'])
    boxes = torch.tensor(boxes, dtype=torch.float32)
    scores = torch.tensor(scores, dtype=torch.float32)
    labels = torch.tensor(labels)

    keep_indices = []
    unique_labels = labels.unique()
    for label in unique_labels:
        idxs = (labels == label).nonzero(as_tuple=False).squeeze(1)
        class_boxes = boxes[idxs]
        class_scores = scores[idxs]
        keep = nms(class_boxes, class_scores, iou_threshold)
        keep_indices.extend(idxs[keep].tolist())

    return [detections[i] for i in keep_indices]

# %%
# Function to get image details by image_id
def get_image_id(coco_data, image_name):
    for image in coco_data["images"]:
        file_name = Path(image['file_name']).stem
        if file_name == image_name:
            return image['id']
    return None

# %%
#rt-detr
input_folder = 'testdev_subsets/medium/v1/images'
for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(input_folder, filename)
            #image_as_pil = read_image_as_pil(image_path)
            filename_without_ext = Path(filename).stem
            
            print("*****************************************")
            print("File Name", filename_without_ext)

            #img_id = get_image_id(data, filename_without_ext)
            #image_ids.append(image_id)

            # Get predictions from your detection model
            #time_start = time.time()
            prediction = get_prediction(image_path, detection_model, verbose=1) #changes
            #time_end = time.time() - time_start
            #print(f"Prediction Performed in {time_end} seconds")
            
            object_density = len(prediction.object_prediction_list)
            print("Object Density:", object_density)
# Out:
# *****************************************
# File Name 9999941_00000_d_0000004
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.39697378873825073, 0, 1.9362149238586426, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.19000637531280518, 0, 1.2901216745376587, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7551359534263611, 0, 1.4047415256500244, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.11324932426214218, 0, 1.075011968612671, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.39511430263519287, 0, 0.6563770174980164, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5747292041778564, 0, 1.7921550273895264, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.0221983194351196, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9663060903549194, 0, 2.0616531372070312, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.12558558583259583, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.09668952971696854, 0, 0.579387366771698, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.18355780839920044, 0, 0.5204954147338867, 0]
# Prediction performed in 4.057074785232544 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000009
# Prediction performed in 0.06939220428466797 seconds.
# Object Density: 0
# *****************************************
# File Name 9999986_00000_d_0000012
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8270357847213745, 0, 1.0690728425979614, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6871408224105835, 0, 1.3846707344055176, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6478931903839111, 0, 1.7645233869552612, 0]
# 04/16/2025 21:02:19 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.003422931768000126, 0, 0.018978264182806015, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.1630393266677856, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.12527112662792206, 0, 1.0896387100219727, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.32297787070274353, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6075077652931213, 0, 1.2861944437026978, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.10744930803775787, 0, 0.23477426171302795, 0]
# Prediction performed in 0.15076708793640137 seconds.
# Object Density: 10
# *****************************************
# File Name 0000063_06000_d_0000007
# Prediction performed in 0.07191967964172363 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000299
# Prediction performed in 0.0737619400024414 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000031
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.36206772923469543, 0, 1.9690922498703003, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5521023869514465, 0, 1.8618098497390747, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.44053423404693604, 0, 1.4490278959274292, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.008932800963521004, 0, 0.2842518389225006, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.299885094165802, 0, 0.6598405241966248, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2622796893119812, 0, 1.1338939666748047, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2834945321083069, 0, 1.1975033283233643, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.734466016292572, 0, 1.743558406829834, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.15017151832580566, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.02685410901904106, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.006087298505008221, 0, 0.060432035475969315, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.08754319697618484, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.4664294421672821, 0, 2.427204132080078, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.128394603729248, 0, 1.953639030456543, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.577152669429779, 0, 1.8923311233520508, 0]
# Prediction performed in 0.07572746276855469 seconds.
# Object Density: 0
# *****************************************
# File Name 0000164_01068_d_0000162
# Prediction performed in 0.06626343727111816 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000191
# Prediction performed in 0.07853150367736816 seconds.
# Object Density: 0
# *****************************************
# File Name 0000272_04000_d_0000009
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7785998582839966, 0, 1.9452910423278809, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7138258814811707, 0, 2.040008544921875, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.036508321762085, 0, 2.8629817962646484, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.009856688790023327, 0, 0.023635264486074448, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.02411257103085518, 0, 0.03970244154334068, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.015618938952684402, 0, 0.09495150297880173, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5077658295631409, 0, 2.461233139038086, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.4682355523109436, 0, 2.284816265106201, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.3984494209289551, 0, 1.3231589794158936, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.023904720321297646, 0, 0.07569994777441025, 0]
# Prediction performed in 0.07803702354431152 seconds.
# Object Density: 0
# *****************************************
# File Name 9999947_00000_d_0000002
# Prediction performed in 0.07602787017822266 seconds.
# Object Density: 6
# *****************************************
# File Name 9999938_00000_d_0000396
# Prediction performed in 0.07371807098388672 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000141
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.09255371987819672, 0, 1.8307157754898071, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.909153938293457, 0, 3.319470167160034, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.6059792041778564, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [2.255760669708252, 0, 3.0199339389801025, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.883201003074646, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0865296125411987, 0, 2.3104987144470215, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0284367799758911, 0, 2.957371234893799, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.2315693348646164, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6443420052528381, 0, 1.1671944856643677, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.35601526498794556, 0, 1.132948398590088, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.024549618363380432, 0, 0.48132431507110596, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8151733875274658, 0, 2.3914616107940674, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.22845502197742462, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.0727744847536087, 0, 0.19255775213241577, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.022856175899505615, 0, 0.09517297148704529, 0]
# Prediction performed in 0.08041787147521973 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000005
# Prediction performed in 0.0766606330871582 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000345
# Prediction performed in 0.07471537590026855 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000128
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9359314441680908, 0, 2.6528868675231934, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.23888064920902252, 0, 0.5549415349960327, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9923229217529297, 0, 2.9086618423461914, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.30311310291290283, 0, 1.123523473739624, 0]
# 04/16/2025 21:02:20 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.12016569077968597, 0, 0.32996729016304016, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.45765602588653564, 0, 2.2528767585754395, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7062223553657532, 0, 1.1328177452087402, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8854678273200989, 0, 2.1057233810424805, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.005949849728494883, 0, 0.43040651082992554, 0]
# Prediction performed in 0.07999205589294434 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000007
# Prediction performed in 0.0727078914642334 seconds.
# Object Density: 0
# *****************************************
# File Name 9999979_00000_d_0000051
# Prediction performed in 0.08083295822143555 seconds.
# Object Density: 7
# *****************************************
# File Name 9999938_00000_d_0000056
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.2185869216918945, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.3601502180099487, 0, 2.3618311882019043, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.3959234654903412, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.1951529085636139, 0, 0.43740513920783997, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2673282027244568, 0, 1.0283384323120117, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.19176384806632996, 0, 0.31674981117248535, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.005006284918636084, 0, 0.22779631614685059, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5583565831184387, 0, 1.9577394723892212, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.5390833616256714, 0, 3.21124529838562, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.04432225972414017, 0, 0.19898800551891327, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.30623096227645874, 0, 1.20636785030365, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.837864100933075, 0, 1.858818769454956, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.11564745008945465, 0, 0.17426571249961853, 0]
# Prediction performed in 0.07561230659484863 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000049
# Prediction performed in 0.07593321800231934 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000392
# Prediction performed in 0.07420778274536133 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000328
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6289438009262085, 0, 1.1194114685058594, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.052207350730896, 0, 2.0921852588653564, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9354939460754395, 0, 1.9915070533752441, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.36487674713134766, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.25506046414375305, 0, 1.0925087928771973, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.04795604199171066, 0, 0.143489271402359, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.2011241465806961, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.06786233931779861, 0, 0.20269452035427094, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.26258325576782227, 0, 1.018683910369873, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.33711689710617065, 0, 0.8792792558670044, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9341040253639221, 0, 2.4198272228240967, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.926183819770813, 0, 2.6072092056274414, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.3657054305076599, 0, 1.422338843345642, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.642862856388092, 0, 0.9001235961914062, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.020139379426836967, 0, 0.054093193262815475, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.5302621126174927, 0]
# Prediction performed in 0.08061838150024414 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000066
# Prediction performed in 0.07766890525817871 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000273
# Prediction performed in 0.07345747947692871 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000202
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5365539789199829, 0, 0.7982373833656311, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5634225010871887, 0, 2.3154354095458984, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.21666447818279266, 0, 1.1374762058258057, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.13392946124076843, 0, 0.24177226424217224, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.0738721415400505, 0, 0.12010131031274796, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.059942010790109634, 0, 0.12575991451740265, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.22798843681812286, 0, 0.39022934436798096, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.1488473415374756, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0432411432266235, 0, 1.248883843421936, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.676650881767273, 0, 1.6891740560531616, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.19243568181991577, 0, 0.5719026923179626, 0]
# 04/16/2025 21:02:21 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2118588387966156, 0, 0.8212566375732422, 0]
# Prediction performed in 0.07446908950805664 seconds.
# Object Density: 0
# *****************************************
# File Name 9999996_00000_d_0000013
# Prediction performed in 0.08077359199523926 seconds.
# Object Density: 6
# *****************************************
# File Name 9999938_00000_d_0000035
# Prediction performed in 0.0756223201751709 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000083
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.1196790933609009, 0, 1.700324535369873, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.47474396228790283, 0, 1.8633631467819214, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6949545741081238, 0, 1.3029146194458008, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.06247391924262047, 0, 0.6271799206733704, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.14669162034988403, 0, 0.3801836669445038, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.039454516023397446, 0, 0.08402299135923386, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5605799555778503, 0, 1.5741866827011108, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.4397132098674774, 0, 1.4484909772872925, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7263846397399902, 0, 1.9715242385864258, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.08027012646198273, 0, 0.18116077780723572, 0]
# Prediction performed in 0.07328486442565918 seconds.
# Object Density: 0
# *****************************************
# File Name 9999963_00000_d_0000068
# Prediction performed in 0.07559990882873535 seconds.
# Object Density: 6
# *****************************************
# File Name 9999938_00000_d_0000475
# Prediction performed in 0.06934118270874023 seconds.
# Object Density: 0
# *****************************************
# File Name 9999979_00000_d_0000015
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8541922569274902, 0, 1.0902231931686401, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6206522583961487, 0, 1.0892486572265625, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.706689715385437, 0, 1.920815110206604, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.44776690006256104, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.4980967342853546, 0, 0.6352173089981079, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.19728107750415802, 0, 1.355025291442871, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.24490204453468323, 0, 1.1370676755905151, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5879207253456116, 0, 1.5758118629455566, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.1756722331047058, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.0330556221306324, 0]
# Prediction performed in 0.07212710380554199 seconds.
# Object Density: 6
# *****************************************
# File Name 9999938_00000_d_0000259
# Prediction performed in 0.07658791542053223 seconds.
# Object Density: 0
# *****************************************
# File Name 0000187_00666_d_0000191
# Prediction performed in 0.06570076942443848 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000112
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.1241307258605957, 0, 2.875286340713501, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.3364417552947998, 0, 4.183070182800293, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5721060037612915, 0, 2.4648325443267822, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.2293517291545868, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.03658454865217209, 0, 0.13371194899082184, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.75480717420578, 0, 2.6470327377319336, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.2405081987380981, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5356869101524353, 0, 2.1117117404937744, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.03849849849939346, 0, 0.1016545444726944, 0]
# Prediction performed in 0.07542109489440918 seconds.
# Object Density: 0
# *****************************************
# File Name 9999963_00000_d_0000070
# Prediction performed in 0.08010268211364746 seconds.
# Object Density: 5
# *****************************************
# File Name 9999952_00000_d_0000295
# Prediction performed in 0.07350397109985352 seconds.
# Object Density: 0
# *****************************************
# File Name 9999986_00000_d_0000005
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5054363012313843, 0, 1.6499916315078735, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.2569838762283325, 0, 2.1453936100006104, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9294019341468811, 0, 2.3327856063842773, 0]
# 04/16/2025 21:02:22 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.24289967119693756, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0734105110168457, 0, 2.987699031829834, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.47911012172698975, 0, 1.7436994314193726, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8436450958251953, 0, 2.2115821838378906, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.061380110681056976, 0, 0.210168719291687, 0]
# Prediction performed in 0.07588934898376465 seconds.
# Object Density: 7
# *****************************************
# File Name 9999952_00000_d_0000096
# Prediction performed in 0.07750058174133301 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000023
# Prediction performed in 0.07338809967041016 seconds.
# Object Density: 0
# *****************************************
# File Name 0000063_05000_d_0000006
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6631463170051575, 0, 1.964269995689392, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.3191811442375183, 0, 1.2111797332763672, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5170853734016418, 0, 0.956264853477478, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.004889640491455793, 0, 0.015962954610586166, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.0016304593300446868, 0, 0.013118536211550236, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6936477422714233, 0, 1.5049245357513428, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8821260929107666, 0, 2.339831590652466, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9441500902175903, 0, 2.6932921409606934, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.04203625023365021, 0, 0.10703861713409424, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.0647883340716362, 0, 0.3334861993789673, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.007687666453421116, 0, 0.019757941365242004, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.37878793478012085, 0, 1.2756479978561401, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2546335756778717, 0, 0.6806276440620422, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7349656820297241, 0, 1.999934434890747, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.09573893994092941, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.40441983938217163, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.2748507857322693, 0]
# Prediction performed in 0.07449531555175781 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000072
# Prediction performed in 0.0735478401184082 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000197
# Prediction performed in 0.07786941528320312 seconds.
# Object Density: 0
# *****************************************
# File Name 9999973_00000_d_0000108
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.383687138557434, 0, 1.5086268186569214, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.6041764616966248, 0, 3.0387191772460938, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.2691117525100708, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.2091304063796997, 0, 1.572653889656067, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0750610828399658, 0, 2.4468159675598145, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7079227566719055, 0, 2.698688507080078, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.167857363820076, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.13911700248718262, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.10079687833786011, 0, 1.177716612815857, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.2667865753173828, 0, 2.5815703868865967, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.9935038089752197, 0, 2.756758689880371, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.01311873272061348, 0, 0.12218330055475235, 0]
# Prediction performed in 0.07950401306152344 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000431
# Prediction performed in 0.06978774070739746 seconds.
# Object Density: 0
# *****************************************
# File Name 0000353_06000_d_0000200
# Prediction performed in 0.07715725898742676 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000425
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.0251556634902954, 0, 3.00087308883667, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.6128135919570923, 0, 2.544419765472412, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.011576102115213871, 0, 0.0765809640288353, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.570732593536377, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.875361442565918, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.051043376326560974, 0, 0.1123717650771141, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.007798433303833, 0, 1.606738567352295, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.12560881674289703, 0, 0.1993785798549652, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.02545635774731636, 0, 0.09740661829710007, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.060149624943733215, 0, 0.09950283169746399, 0]
# Prediction performed in 0.07327938079833984 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000248
# Prediction performed in 0.07347798347473145 seconds.
# Object Density: 0
# *****************************************
# File Name 9999963_00000_d_0000018
# Prediction performed in 0.07552528381347656 seconds.
# Object Density: 6
# *****************************************
# File Name 9999952_00000_d_0000081
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.2774902284145355, 0, 1.0546380281448364, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.5845552682876587, 0, 1.4342870712280273, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.7685941457748413, 0, 1.8471887111663818, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.12444552779197693, 0, 0.3164684474468231, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 1.2962369918823242, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.8606833815574646, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8687300086021423, 0, 1.3633226156234741, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.0006034551188349724, 0, 0.7967632412910461, 0]
# 04/16/2025 21:02:23 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.41824501752853394, 0, 0.6540447473526001, 0]
# 04/16/2025 21:02:24 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0, 0, 0.7117316722869873, 0]
# 04/16/2025 21:02:24 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.8435107469558716, 0, 1.0676286220550537, 0]
# 04/16/2025 21:02:24 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.029229512438178062, 0, 0.07576275616884232, 0]
# 04/16/2025 21:02:24 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [1.161228895187378, 0, 1.398964285850525, 0]
# 04/16/2025 21:02:24 - WARNING - sahi.models.ultralytics -   ignoring invalid prediction with bbox: [0.00627951230853796, 0, 0.08226892352104187, 0]
# Prediction performed in 0.07703733444213867 seconds.
# Object Density: 0
# *****************************************
# File Name 9999938_00000_d_0000323
# Prediction performed in 0.07744169235229492 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000062
# Prediction performed in 0.07844114303588867 seconds.
# Object Density: 0

# %%
#yolov8
input_folder = 'testdev_subsets/medium/v1/images'
for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(input_folder, filename)
            #image_as_pil = read_image_as_pil(image_path)
            filename_without_ext = Path(filename).stem
            
            print("*****************************************")
            print("File Name", filename_without_ext)

            #img_id = get_image_id(data, filename_without_ext)
            #image_ids.append(image_id)

            # Get predictions from your detection model
            #time_start = time.time()
            prediction = get_prediction(image_path, detection_model, verbose=1) #changes
            #time_end = time.time() - time_start
            #print(f"Prediction Performed in {time_end} seconds")
            
            object_density = len(prediction.object_prediction_list)
            print("Object Density:", object_density)
# Out:
# *****************************************
# File Name 9999941_00000_d_0000004
# Prediction performed in 0.015785694122314453 seconds.
# Object Density: 28
# *****************************************
# File Name 9999938_00000_d_0000009
# Prediction performed in 0.013902902603149414 seconds.
# Object Density: 26
# *****************************************
# File Name 9999986_00000_d_0000012
# Prediction performed in 0.08486056327819824 seconds.
# Object Density: 19
# *****************************************
# File Name 0000063_06000_d_0000007
# Prediction performed in 0.009827613830566406 seconds.
# Object Density: 30
# *****************************************
# File Name 9999938_00000_d_0000299
# Prediction performed in 0.013421773910522461 seconds.
# Object Density: 30
# *****************************************
# File Name 9999938_00000_d_0000031
# Prediction performed in 0.013299703598022461 seconds.
# Object Density: 31
# *****************************************
# File Name 0000164_01068_d_0000162
# Prediction performed in 0.00941324234008789 seconds.
# Object Density: 20
# *****************************************
# File Name 9999952_00000_d_0000191
# Prediction performed in 0.01337122917175293 seconds.
# Object Density: 15
# *****************************************
# File Name 0000272_04000_d_0000009
# Prediction performed in 0.012700080871582031 seconds.
# Object Density: 28
# *****************************************
# File Name 9999947_00000_d_0000002
# Prediction performed in 0.016266584396362305 seconds.
# Object Density: 25
# *****************************************
# File Name 9999938_00000_d_0000396
# Prediction performed in 0.013598918914794922 seconds.
# Object Density: 23
# *****************************************
# File Name 9999973_00000_d_0000141
# Prediction performed in 0.019281864166259766 seconds.
# Object Density: 19
# *****************************************
# File Name 9999973_00000_d_0000005
# Prediction performed in 0.019414424896240234 seconds.
# Object Density: 14
# *****************************************
# File Name 9999938_00000_d_0000345
# Prediction performed in 0.013347864151000977 seconds.
# Object Density: 26
# *****************************************
# File Name 9999973_00000_d_0000128
# Prediction performed in 0.019797801971435547 seconds.
# Object Density: 21
# *****************************************
# File Name 9999938_00000_d_0000007
# Prediction performed in 0.013359785079956055 seconds.
# Object Density: 27
# *****************************************
# File Name 9999979_00000_d_0000051
# Prediction performed in 0.016324758529663086 seconds.
# Object Density: 20
# *****************************************
# File Name 9999938_00000_d_0000056
# Prediction performed in 0.013643503189086914 seconds.
# Object Density: 21
# *****************************************
# File Name 9999973_00000_d_0000049
# Prediction performed in 0.019191741943359375 seconds.
# Object Density: 15
# *****************************************
# File Name 9999938_00000_d_0000392
# Prediction performed in 0.013348579406738281 seconds.
# Object Density: 10
# *****************************************
# File Name 9999938_00000_d_0000328
# Prediction performed in 0.01327204704284668 seconds.
# Object Density: 14
# *****************************************
# File Name 9999952_00000_d_0000066
# Prediction performed in 0.013264179229736328 seconds.
# Object Density: 10
# *****************************************
# File Name 9999938_00000_d_0000273
# Prediction performed in 0.01318669319152832 seconds.
# Object Density: 34
# *****************************************
# File Name 9999952_00000_d_0000202
# Prediction performed in 0.013155698776245117 seconds.
# Object Density: 24
# *****************************************
# File Name 9999996_00000_d_0000013
# Prediction performed in 0.016376972198486328 seconds.
# Object Density: 22
# *****************************************
# File Name 9999938_00000_d_0000035
# Prediction performed in 0.013636112213134766 seconds.
# Object Density: 19
# *****************************************
# File Name 9999952_00000_d_0000083
# Prediction performed in 0.013194799423217773 seconds.
# Object Density: 7
# *****************************************
# File Name 9999963_00000_d_0000068
# Prediction performed in 0.01632070541381836 seconds.
# Object Density: 28
# *****************************************
# File Name 9999938_00000_d_0000475
# Prediction performed in 0.013757944107055664 seconds.
# Object Density: 28
# *****************************************
# File Name 9999979_00000_d_0000015
# Prediction performed in 0.0163729190826416 seconds.
# Object Density: 31
# *****************************************
# File Name 9999938_00000_d_0000259
# Prediction performed in 0.013673782348632812 seconds.
# Object Density: 24
# *****************************************
# File Name 0000187_00666_d_0000191
# Prediction performed in 0.009466409683227539 seconds.
# Object Density: 17
# *****************************************
# File Name 9999973_00000_d_0000112
# Prediction performed in 0.01918315887451172 seconds.
# Object Density: 21
# *****************************************
# File Name 9999963_00000_d_0000070
# Prediction performed in 0.016418933868408203 seconds.
# Object Density: 27
# *****************************************
# File Name 9999952_00000_d_0000295
# Prediction performed in 0.013756036758422852 seconds.
# Object Density: 23
# *****************************************
# File Name 9999986_00000_d_0000005
# Prediction performed in 0.01628851890563965 seconds.
# Object Density: 15
# *****************************************
# File Name 9999952_00000_d_0000096
# Prediction performed in 0.013700485229492188 seconds.
# Object Density: 13
# *****************************************
# File Name 9999938_00000_d_0000023
# Prediction performed in 0.013817787170410156 seconds.
# Object Density: 10
# *****************************************
# File Name 0000063_05000_d_0000006
# Prediction performed in 0.00941777229309082 seconds.
# Object Density: 32
# *****************************************
# File Name 9999938_00000_d_0000072
# Prediction performed in 0.013372659683227539 seconds.
# Object Density: 20
# *****************************************
# File Name 9999952_00000_d_0000197
# Prediction performed in 0.01329493522644043 seconds.
# Object Density: 31
# *****************************************
# File Name 9999973_00000_d_0000108
# Prediction performed in 0.019263267517089844 seconds.
# Object Density: 16
# *****************************************
# File Name 9999938_00000_d_0000431
# Prediction performed in 0.013469457626342773 seconds.
# Object Density: 20
# *****************************************
# File Name 0000353_06000_d_0000200
# Prediction performed in 0.012847661972045898 seconds.
# Object Density: 19
# *****************************************
# File Name 9999938_00000_d_0000425
# Prediction performed in 0.013346672058105469 seconds.
# Object Density: 35
# *****************************************
# File Name 9999938_00000_d_0000248
# Prediction performed in 0.013119220733642578 seconds.
# Object Density: 35
# *****************************************
# File Name 9999963_00000_d_0000018
# Prediction performed in 0.01627349853515625 seconds.
# Object Density: 30
# *****************************************
# File Name 9999952_00000_d_0000081
# Prediction performed in 0.013789653778076172 seconds.
# Object Density: 11
# *****************************************
# File Name 9999938_00000_d_0000323
# Prediction performed in 0.013285636901855469 seconds.
# Object Density: 16
# *****************************************
# File Name 9999952_00000_d_0000062
# Prediction performed in 0.013257265090942383 seconds.
# Object Density: 11

# %%
#yolov11
input_folder = 'testdev_subsets/medium/v1/images'
for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(input_folder, filename)
            #image_as_pil = read_image_as_pil(image_path)
            filename_without_ext = Path(filename).stem
            
            print("*****************************************")
            print("File Name", filename_without_ext)

            #img_id = get_image_id(data, filename_without_ext)
            #image_ids.append(image_id)

            # Get predictions from your detection model
            #time_start = time.time()
            prediction = get_prediction(image_path, detection_model, verbose=1) #changes
            #time_end = time.time() - time_start
            #print(f"Prediction Performed in {time_end} seconds")
            
            object_density = len(prediction.object_prediction_list)
            print("Object Density:", object_density)
# Out:
# *****************************************
# File Name 9999941_00000_d_0000004
# Prediction performed in 0.737584114074707 seconds.
# Object Density: 27
# *****************************************
# File Name 9999938_00000_d_0000009
# Prediction performed in 0.015390872955322266 seconds.
# Object Density: 27
# *****************************************
# File Name 9999986_00000_d_0000012
# Prediction performed in 0.056285858154296875 seconds.
# Object Density: 25
# *****************************************
# File Name 0000063_06000_d_0000007
# Prediction performed in 0.011892318725585938 seconds.
# Object Density: 31
# *****************************************
# File Name 9999938_00000_d_0000299
# Prediction performed in 0.014685869216918945 seconds.
# Object Density: 26
# *****************************************
# File Name 9999938_00000_d_0000031
# Prediction performed in 0.014840364456176758 seconds.
# Object Density: 30
# *****************************************
# File Name 0000164_01068_d_0000162
# Prediction performed in 0.010972738265991211 seconds.
# Object Density: 16
# *****************************************
# File Name 9999952_00000_d_0000191
# Prediction performed in 0.01473379135131836 seconds.
# Object Density: 12
# *****************************************
# File Name 0000272_04000_d_0000009
# Prediction performed in 0.014247894287109375 seconds.
# Object Density: 28
# *****************************************
# File Name 9999947_00000_d_0000002
# Prediction performed in 0.018358230590820312 seconds.
# Object Density: 14
# *****************************************
# File Name 9999938_00000_d_0000396
# Prediction performed in 0.015316486358642578 seconds.
# Object Density: 26
# *****************************************
# File Name 9999973_00000_d_0000141
# Prediction performed in 0.02157139778137207 seconds.
# Object Density: 21
# *****************************************
# File Name 9999973_00000_d_0000005
# Prediction performed in 0.021265029907226562 seconds.
# Object Density: 12
# *****************************************
# File Name 9999938_00000_d_0000345
# Prediction performed in 0.015087366104125977 seconds.
# Object Density: 24
# *****************************************
# File Name 9999973_00000_d_0000128
# Prediction performed in 0.02099132537841797 seconds.
# Object Density: 31
# *****************************************
# File Name 9999938_00000_d_0000007
# Prediction performed in 0.015063047409057617 seconds.
# Object Density: 28
# *****************************************
# File Name 9999979_00000_d_0000051
# Prediction performed in 0.018132448196411133 seconds.
# Object Density: 19
# *****************************************
# File Name 9999938_00000_d_0000056
# Prediction performed in 0.015321731567382812 seconds.
# Object Density: 21
# *****************************************
# File Name 9999973_00000_d_0000049
# Prediction performed in 0.020874977111816406 seconds.
# Object Density: 16
# *****************************************
# File Name 9999938_00000_d_0000392
# Prediction performed in 0.014989614486694336 seconds.
# Object Density: 8
# *****************************************
# File Name 9999938_00000_d_0000328
# Prediction performed in 0.014838218688964844 seconds.
# Object Density: 9
# *****************************************
# File Name 9999952_00000_d_0000066
# Prediction performed in 0.014772891998291016 seconds.
# Object Density: 11
# *****************************************
# File Name 9999938_00000_d_0000273
# Prediction performed in 0.014770746231079102 seconds.
# Object Density: 31
# *****************************************
# File Name 9999952_00000_d_0000202
# Prediction performed in 0.014805793762207031 seconds.
# Object Density: 26
# *****************************************
# File Name 9999996_00000_d_0000013
# Prediction performed in 0.017889976501464844 seconds.
# Object Density: 21
# *****************************************
# File Name 9999938_00000_d_0000035
# Prediction performed in 0.015332221984863281 seconds.
# Object Density: 19
# *****************************************
# File Name 9999952_00000_d_0000083
# Prediction performed in 0.014800310134887695 seconds.
# Object Density: 17
# *****************************************
# File Name 9999963_00000_d_0000068
# Prediction performed in 0.017739057540893555 seconds.
# Object Density: 30
# *****************************************
# File Name 9999938_00000_d_0000475
# Prediction performed in 0.015330314636230469 seconds.
# Object Density: 25
# *****************************************
# File Name 9999979_00000_d_0000015
# Prediction performed in 0.018083572387695312 seconds.
# Object Density: 32
# *****************************************
# File Name 9999938_00000_d_0000259
# Prediction performed in 0.015296459197998047 seconds.
# Object Density: 24
# *****************************************
# File Name 0000187_00666_d_0000191
# Prediction performed in 0.011016368865966797 seconds.
# Object Density: 15
# *****************************************
# File Name 9999973_00000_d_0000112
# Prediction performed in 0.020837783813476562 seconds.
# Object Density: 13
# *****************************************
# File Name 9999963_00000_d_0000070
# Prediction performed in 0.0181424617767334 seconds.
# Object Density: 35
# *****************************************
# File Name 9999952_00000_d_0000295
# Prediction performed in 0.015325069427490234 seconds.
# Object Density: 23
# *****************************************
# File Name 9999986_00000_d_0000005
# Prediction performed in 0.01794719696044922 seconds.
# Object Density: 15
# *****************************************
# File Name 9999952_00000_d_0000096
# Prediction performed in 0.015308856964111328 seconds.
# Object Density: 12
# *****************************************
# File Name 9999938_00000_d_0000023
# Prediction performed in 0.01485300064086914 seconds.
# Object Density: 8
# *****************************************
# File Name 0000063_05000_d_0000006
# Prediction performed in 0.011057853698730469 seconds.
# Object Density: 25
# *****************************************
# File Name 9999938_00000_d_0000072
# Prediction performed in 0.014725446701049805 seconds.
# Object Density: 16
# *****************************************
# File Name 9999952_00000_d_0000197
# Prediction performed in 0.014822721481323242 seconds.
# Object Density: 28
# *****************************************
# File Name 9999973_00000_d_0000108
# Prediction performed in 0.020836830139160156 seconds.
# Object Density: 15
# *****************************************
# File Name 9999938_00000_d_0000431
# Prediction performed in 0.01517939567565918 seconds.
# Object Density: 15
# *****************************************
# File Name 0000353_06000_d_0000200
# Prediction performed in 0.01436161994934082 seconds.
# Object Density: 20
# *****************************************
# File Name 9999938_00000_d_0000425
# Prediction performed in 0.014791488647460938 seconds.
# Object Density: 21
# *****************************************
# File Name 9999938_00000_d_0000248
# Prediction performed in 0.014765501022338867 seconds.
# Object Density: 43
# *****************************************
# File Name 9999963_00000_d_0000018
# Prediction performed in 0.017750024795532227 seconds.
# Object Density: 34
# *****************************************
# File Name 9999952_00000_d_0000081
# Prediction performed in 0.015329599380493164 seconds.
# Object Density: 12
# *****************************************
# File Name 9999938_00000_d_0000323
# Prediction performed in 0.014885425567626953 seconds.
# Object Density: 13
# *****************************************
# File Name 9999952_00000_d_0000062
# Prediction performed in 0.014759302139282227 seconds.
# Object Density: 8

# %%
#yolov8
input_folder = 'testdev_subsets/sparse/v1/images'
for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_path = os.path.join(input_folder, filename)
            #image_as_pil = read_image_as_pil(image_path)
            filename_without_ext = Path(filename).stem
            
            print("*****************************************")
            print("File Name", filename_without_ext)

            #img_id = get_image_id(data, filename_without_ext)
            #image_ids.append(image_id)

            # Get predictions from your detection model
            #time_start = time.time()
            prediction = get_prediction(image_path, detection_model, verbose=1) #changes
            #time_end = time.time() - time_start
            #print(f"Prediction Performed in {time_end} seconds")
            
            object_density = len(prediction.object_prediction_list)
            print("Object Density:", object_density)
# Out:
# *****************************************
# File Name 9999973_00000_d_0000054
# Prediction performed in 0.07944846153259277 seconds.
# Object Density: 14
# *****************************************
# File Name 9999986_00000_d_0000027
# Prediction performed in 0.0166776180267334 seconds.
# Object Density: 5
# *****************************************
# File Name 9999973_00000_d_0000126
# Prediction performed in 0.01986527442932129 seconds.
# Object Density: 8
# *****************************************
# File Name 9999938_00000_d_0000476
# Prediction performed in 0.013657331466674805 seconds.
# Object Density: 17
# *****************************************
# File Name 0000078_05467_d_0000015
# Prediction performed in 0.012717485427856445 seconds.
# Object Density: 3
# *****************************************
# File Name 9999952_00000_d_0000178
# Prediction performed in 0.013298749923706055 seconds.
# Object Density: 9
# *****************************************
# File Name 9999938_00000_d_0000322
# Prediction performed in 0.013139486312866211 seconds.
# Object Density: 8
# *****************************************
# File Name 9999938_00000_d_0000439
# Prediction performed in 0.013131856918334961 seconds.
# Object Density: 6
# *****************************************
# File Name 9999952_00000_d_0000209
# Prediction performed in 0.013070106506347656 seconds.
# Object Density: 9
# *****************************************
# File Name 9999952_00000_d_0000129
# Prediction performed in 0.013138294219970703 seconds.
# Object Density: 5
# *****************************************
# File Name 9999952_00000_d_0000190
# Prediction performed in 0.013355255126953125 seconds.
# Object Density: 10
# *****************************************
# File Name 9999952_00000_d_0000224
# Prediction performed in 0.013103961944580078 seconds.
# Object Density: 9
# *****************************************
# File Name 9999952_00000_d_0000259
# Prediction performed in 0.01297903060913086 seconds.
# Object Density: 1
# *****************************************
# File Name 9999938_00000_d_0000443
# Prediction performed in 0.013077974319458008 seconds.
# Object Density: 13
# *****************************************
# File Name 9999938_00000_d_0000091
# Prediction performed in 0.013123512268066406 seconds.
# Object Density: 8
# *****************************************
# File Name 0000006_05208_d_0000014
# Prediction performed in 0.012670755386352539 seconds.
# Object Density: 17
# *****************************************
# File Name 9999938_00000_d_0000474
# Prediction performed in 0.013299942016601562 seconds.
# Object Density: 19
# *****************************************
# File Name 9999976_00000_d_0000013
# Prediction performed in 0.013156890869140625 seconds.
# Object Density: 7
# *****************************************
# File Name 9999938_00000_d_0000488
# Prediction performed in 0.013051509857177734 seconds.
# Object Density: 12
# *****************************************
# File Name 9999973_00000_d_0000055
# Prediction performed in 0.019382476806640625 seconds.
# Object Density: 11
# *****************************************
# File Name 9999938_00000_d_0000150
# Prediction performed in 0.01463937759399414 seconds.
# Object Density: 6
# *****************************************
# File Name 9999976_00000_d_0000014
# Prediction performed in 0.014234066009521484 seconds.
# Object Density: 5
# *****************************************
# File Name 9999986_00000_d_0000028
# Prediction performed in 0.01658344268798828 seconds.
# Object Density: 7
# *****************************************
# File Name 0000120_01535_d_0000095
# Prediction performed in 0.013772010803222656 seconds.
# Object Density: 7
# *****************************************
# File Name 9999976_00000_d_0000023
# Prediction performed in 0.013349294662475586 seconds.
# Object Density: 10
# *****************************************
# File Name 9999952_00000_d_0000257
# Prediction performed in 0.013826131820678711 seconds.
# Object Density: 0
# *****************************************
# File Name 9999952_00000_d_0000305
# Prediction performed in 0.013278961181640625 seconds.
# Object Density: 13
# *****************************************
# File Name 9999952_00000_d_0000032
# Prediction performed in 0.013150215148925781 seconds.
# Object Density: 13
# *****************************************
# File Name 9999952_00000_d_0000185
# Prediction performed in 0.01306009292602539 seconds.
# Object Density: 2
# *****************************************
# File Name 0000078_04210_d_0000012
# Prediction performed in 0.012708663940429688 seconds.
# Object Density: 2
# *****************************************
# File Name 9999952_00000_d_0000287
# Prediction performed in 0.013275146484375 seconds.
# Object Density: 9
# *****************************************
# File Name 9999996_00000_d_0000023
# Prediction performed in 0.01645517349243164 seconds.
# Object Density: 0
# *****************************************
# File Name 9999976_00000_d_0000004
# Prediction performed in 0.013814210891723633 seconds.
# Object Density: 14
# *****************************************
# File Name 9999938_00000_d_0000515
# Prediction performed in 0.013095855712890625 seconds.
# Object Density: 8
# *****************************************
# File Name 9999952_00000_d_0000108
# Prediction performed in 0.01320505142211914 seconds.
# Object Density: 7
# *****************************************
# File Name 9999938_00000_d_0000309
# Prediction performed in 0.013101816177368164 seconds.
# Object Density: 5
# *****************************************
# File Name 9999952_00000_d_0000319
# Prediction performed in 0.013180732727050781 seconds.
# Object Density: 8
# *****************************************
# File Name 9999952_00000_d_0000207
# Prediction performed in 0.013412714004516602 seconds.
# Object Density: 17
# *****************************************
# File Name 9999952_00000_d_0000184
# Prediction performed in 0.013111591339111328 seconds.
# Object Density: 4
# *****************************************
# File Name 9999938_00000_d_0000158
# Prediction performed in 0.013586044311523438 seconds.
# Object Density: 6
# *****************************************
# File Name 9999938_00000_d_0000510
# Prediction performed in 0.01321554183959961 seconds.
# Object Density: 14
# *****************************************
# File Name 9999952_00000_d_0000079
# Prediction performed in 0.013100862503051758 seconds.
# Object Density: 15
# *****************************************
# File Name 9999952_00000_d_0000216
# Prediction performed in 0.013129472732543945 seconds.
# Object Density: 17
# *****************************************
# File Name 0000370_03000_d_0000256
# Prediction performed in 0.012630701065063477 seconds.
# Object Density: 4
# *****************************************
# File Name 9999952_00000_d_0000006
# Prediction performed in 0.01322174072265625 seconds.
# Object Density: 6
# *****************************************
# File Name 9999980_00000_d_0000004
# Prediction performed in 0.01644420623779297 seconds.
# Object Density: 3
# *****************************************
# File Name 9999952_00000_d_0000050
# Prediction performed in 0.01388859748840332 seconds.
# Object Density: 15
# *****************************************
# File Name 0000078_06777_d_0000020
# Prediction performed in 0.01261281967163086 seconds.
# Object Density: 3
# *****************************************
# File Name 9999938_00000_d_0000344
# Prediction performed in 0.013541698455810547 seconds.
# Object Density: 15
# *****************************************
# File Name 9999973_00000_d_0000094
# Prediction performed in 0.01968240737915039 seconds.
# Object Density: 5

# %%
import pandas as pd
from scipy.stats import pearsonr

# -------------------------------
# Configuration: file names and column names
# -------------------------------
predicted_file = 'predicted_outputs.xlsx'      # Excel file containing predicted counts
ground_truth_file = 'medium_gt.xlsx'  # Excel file containing ground truth counts
output_file = 'output_analysis.xlsx'            # Output Excel file name

# Define the column names. Adjust these names if your files have different headers.
id_column = 'file_name'              # Column to merge on, e.g., an image identifier
predicted_count_column = 'predict_bbox_count'
ground_truth_count_column = 'gt_bbox_count'

# -------------------------------
# Read the Excel files
# -------------------------------
predicted_df = pd.read_excel(predicted_file)
ground_truth_df = pd.read_excel(ground_truth_file)

# -------------------------------
# Merge the dataframes on the common identifier
# -------------------------------
merged_df = pd.merge(predicted_df, ground_truth_df, on=id_column, how='inner')
print()
# -------------------------------
# Calculate the difference in counts
# -------------------------------
# Here the difference is calculated as ground truth minus predicted count.
merged_df['Difference'] = abs(merged_df[ground_truth_count_column] - merged_df[predicted_count_column])

# -------------------------------
# Calculate the Pearson correlation coefficient
# -------------------------------
pearson_corr, p_value = pearsonr(merged_df[predicted_count_column], merged_df[ground_truth_count_column])
print(f"Pearson Correlation Coefficient: {pearson_corr}, P-value: {p_value}")

# Create a summary dataframe for correlation results
corr_df = pd.DataFrame({
    'Pearson_Correlation': [pearson_corr],
    'P_value': [p_value]
})

# -------------------------------
# Save the output to an Excel file with two sheets:
# - One sheet for the merged counts and differences.
# - One sheet for the correlation results.
# -------------------------------
with pd.ExcelWriter(output_file) as writer:
    merged_df.to_excel(writer, sheet_name='Counts_and_Differences', index=False)
    corr_df.to_excel(writer, sheet_name='Correlation', index=False)

print(f"Results successfully saved to {output_file}")
# Out:
# Pearson Correlation Coefficient: 0.09073230368456274, P-value: 0.5308941754499572
# Results successfully saved to output_analysis.xlsx

# %%
import os
from pathlib import Path
import pandas as pd
from scipy.stats import pearsonr
import time

# -------------------------------
# Configuration: file paths and column names
# -------------------------------
input_folder = 'testdev_subsets/medium/v1/images'  # Folder with images
predicted_output_file = 'predicted_outputs.xlsx'      # Excel file with ground truth counts


# -------------------------------
# Step 1: Process images and obtain predictions
# -------------------------------
predicted_data = []

# Iterate through each file in the input folder
for filename in os.listdir(input_folder):
    # Check if the file is an image
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(input_folder, filename)
        filename_without_ext = Path(filename).stem
        
        print("*****************************************")
        print("File Name:", filename_without_ext)
        
        # Get predictions from your detection model.
        # It is assumed that 'get_prediction' and 'detection_model' are defined elsewhere.
        # Optionally, you can time this prediction step.
        # time_start = time.time()
        prediction = get_prediction(image_path, detection_model, verbose=1)
        # time_end = time.time() - time_start
        # print(f"Prediction performed in {time_end:.2f} seconds")
        
        # Calculate the object density (predicted count)
        object_density = len(prediction.object_prediction_list)
        print("Object Density:", object_density)
        
        # Store the result for this image
        predicted_data.append({
            'file_name': filename,
            'bbox_count': object_density
        })

# Convert the list of predicted counts to a DataFrame
predicted_df = pd.DataFrame(predicted_data)

# Save the merged DataFrame to an Excel file with one sheet
predicted_df.to_excel(predicted_output_file, sheet_name='Results', index=False)
print(f"Analysis results saved to {predicted_output_file}")
# Out:
# *****************************************
# File Name: 9999941_00000_d_0000004
# Prediction performed in 0.013935565948486328 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999938_00000_d_0000009
# Prediction performed in 0.013425827026367188 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999986_00000_d_0000012
# Prediction performed in 0.016100168228149414 seconds.
# Object Density: 19
# *****************************************
# File Name: 0000063_06000_d_0000007
# Prediction performed in 0.010104179382324219 seconds.
# Object Density: 30
# *****************************************
# File Name: 9999938_00000_d_0000299
# Prediction performed in 0.012789249420166016 seconds.
# Object Density: 30
# *****************************************
# File Name: 9999938_00000_d_0000031
# Prediction performed in 0.013325214385986328 seconds.
# Object Density: 31
# *****************************************
# File Name: 0000164_01068_d_0000162
# Prediction performed in 0.009385108947753906 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999952_00000_d_0000191
# Prediction performed in 0.013432741165161133 seconds.
# Object Density: 15
# *****************************************
# File Name: 0000272_04000_d_0000009
# Prediction performed in 0.013012886047363281 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999947_00000_d_0000002
# Prediction performed in 0.01621699333190918 seconds.
# Object Density: 25
# *****************************************
# File Name: 9999938_00000_d_0000396
# Prediction performed in 0.013568401336669922 seconds.
# Object Density: 23
# *****************************************
# File Name: 9999973_00000_d_0000141
# Prediction performed in 0.01918506622314453 seconds.
# Object Density: 19
# *****************************************
# File Name: 9999973_00000_d_0000005
# Prediction performed in 0.019444704055786133 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999938_00000_d_0000345
# Prediction performed in 0.013401985168457031 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999973_00000_d_0000128
# Prediction performed in 0.0194094181060791 seconds.
# Object Density: 21
# *****************************************
# File Name: 9999938_00000_d_0000007
# Prediction performed in 0.013437032699584961 seconds.
# Object Density: 27
# *****************************************
# File Name: 9999979_00000_d_0000051
# Prediction performed in 0.016292333602905273 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000056
# Prediction performed in 0.013664484024047852 seconds.
# Object Density: 21
# *****************************************
# File Name: 9999973_00000_d_0000049
# Prediction performed in 0.01947927474975586 seconds.
# Object Density: 15
# *****************************************
# File Name: 9999938_00000_d_0000392
# Prediction performed in 0.013449668884277344 seconds.
# Object Density: 10
# *****************************************
# File Name: 9999938_00000_d_0000328
# Prediction performed in 0.013156652450561523 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999952_00000_d_0000066
# Prediction performed in 0.013380289077758789 seconds.
# Object Density: 10
# *****************************************
# File Name: 9999938_00000_d_0000273
# Prediction performed in 0.013184070587158203 seconds.
# Object Density: 34
# *****************************************
# File Name: 9999952_00000_d_0000202
# Prediction performed in 0.01341390609741211 seconds.
# Object Density: 24
# *****************************************
# File Name: 9999996_00000_d_0000013
# Prediction performed in 0.016230106353759766 seconds.
# Object Density: 22
# *****************************************
# File Name: 9999938_00000_d_0000035
# Prediction performed in 0.013783454895019531 seconds.
# Object Density: 19
# *****************************************
# File Name: 9999952_00000_d_0000083
# Prediction performed in 0.01292562484741211 seconds.
# Object Density: 7
# *****************************************
# File Name: 9999963_00000_d_0000068
# Prediction performed in 0.016393423080444336 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999938_00000_d_0000475
# Prediction performed in 0.013664960861206055 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999979_00000_d_0000015
# Prediction performed in 0.01615762710571289 seconds.
# Object Density: 31
# *****************************************
# File Name: 9999938_00000_d_0000259
# Prediction performed in 0.013993501663208008 seconds.
# Object Density: 24
# *****************************************
# File Name: 0000187_00666_d_0000191
# Prediction performed in 0.009625434875488281 seconds.
# Object Density: 17
# *****************************************
# File Name: 9999973_00000_d_0000112
# Prediction performed in 0.019404172897338867 seconds.
# Object Density: 21
# *****************************************
# File Name: 9999963_00000_d_0000070
# Prediction performed in 0.01662755012512207 seconds.
# Object Density: 27
# *****************************************
# File Name: 9999952_00000_d_0000295
# Prediction performed in 0.013521909713745117 seconds.
# Object Density: 23
# *****************************************
# File Name: 9999986_00000_d_0000005
# Prediction performed in 0.016230106353759766 seconds.
# Object Density: 15
# *****************************************
# File Name: 9999952_00000_d_0000096
# Prediction performed in 0.013677120208740234 seconds.
# Object Density: 13
# *****************************************
# File Name: 9999938_00000_d_0000023
# Prediction performed in 0.013010978698730469 seconds.
# Object Density: 10
# *****************************************
# File Name: 0000063_05000_d_0000006
# Prediction performed in 0.0095367431640625 seconds.
# Object Density: 32
# *****************************************
# File Name: 9999938_00000_d_0000072
# Prediction performed in 0.013028621673583984 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999952_00000_d_0000197
# Prediction performed in 0.013494729995727539 seconds.
# Object Density: 31
# *****************************************
# File Name: 9999973_00000_d_0000108
# Prediction performed in 0.019355297088623047 seconds.
# Object Density: 16
# *****************************************
# File Name: 9999938_00000_d_0000431
# Prediction performed in 0.013402223587036133 seconds.
# Object Density: 20
# *****************************************
# File Name: 0000353_06000_d_0000200
# Prediction performed in 0.012558698654174805 seconds.
# Object Density: 19
# *****************************************
# File Name: 9999938_00000_d_0000425
# Prediction performed in 0.013366937637329102 seconds.
# Object Density: 35
# *****************************************
# File Name: 9999938_00000_d_0000248
# Prediction performed in 0.013395547866821289 seconds.
# Object Density: 35
# *****************************************
# File Name: 9999963_00000_d_0000018
# Prediction performed in 0.016330957412719727 seconds.
# Object Density: 30
# *****************************************
# File Name: 9999952_00000_d_0000081
# Prediction performed in 0.013772249221801758 seconds.
# Object Density: 11
# *****************************************
# File Name: 9999938_00000_d_0000323
# Prediction performed in 0.01299738883972168 seconds.
# Object Density: 16
# *****************************************
# File Name: 9999952_00000_d_0000062
# Prediction performed in 0.013436317443847656 seconds.
# Object Density: 11
# Analysis results saved to predicted_outputs.xlsx

# %%
import os
from pathlib import Path
import pandas as pd
from scipy.stats import pearsonr
import time

# -------------------------------
# Configuration: file paths and column names
# -------------------------------
input_folder = 'testdev_subsets/medium/v1/images'  # Folder with images
predicted_output_file = 'predicted_outputs.xlsx'      # Excel file with ground truth counts


# -------------------------------
# Step 1: Process images and obtain predictions
# -------------------------------
predicted_data = []

# Iterate through each file in the input folder
for filename in os.listdir(input_folder):
    # Check if the file is an image
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        image_path = os.path.join(input_folder, filename)
        filename_without_ext = Path(filename).stem
        
        print("*****************************************")
        print("File Name:", filename_without_ext)
        
        # Get predictions from your detection model.
        # It is assumed that 'get_prediction' and 'detection_model' are defined elsewhere.
        # Optionally, you can time this prediction step.
        # time_start = time.time()
        prediction = get_prediction(image_path, detection_model, verbose=1)
        # time_end = time.time() - time_start
        # print(f"Prediction performed in {time_end:.2f} seconds")
        
        # Calculate the object density (predicted count)
        object_density = len(prediction.object_prediction_list)
        print("Object Density:", object_density)
        
        # Store the result for this image
        predicted_data.append({
            'file_name': filename,
            'bbox_count': object_density
        })

# Convert the list of predicted counts to a DataFrame
predicted_df = pd.DataFrame(predicted_data)

# Save the merged DataFrame to an Excel file with one sheet
predicted_df.to_excel(predicted_output_file, sheet_name='Results', index=False)
print(f"Analysis results saved to {predicted_output_file}")
# Out:
# *****************************************
# File Name: 9999941_00000_d_0000004
# Prediction performed in 2.0927417278289795 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999938_00000_d_0000009
# Prediction performed in 0.016286849975585938 seconds.
# Object Density: 27
# *****************************************
# File Name: 9999986_00000_d_0000012
# Prediction performed in 0.09188556671142578 seconds.
# Object Density: 22
# *****************************************
# File Name: 0000063_06000_d_0000007
# Prediction performed in 0.011777162551879883 seconds.
# Object Density: 30
# *****************************************
# File Name: 9999938_00000_d_0000299
# Prediction performed in 0.015300512313842773 seconds.
# Object Density: 27
# *****************************************
# File Name: 9999938_00000_d_0000031
# Prediction performed in 0.015184164047241211 seconds.
# Object Density: 23
# *****************************************
# File Name: 0000164_01068_d_0000162
# Prediction performed in 0.011291980743408203 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999952_00000_d_0000191
# Prediction performed in 0.01523733139038086 seconds.
# Object Density: 14
# *****************************************
# File Name: 0000272_04000_d_0000009
# Prediction performed in 0.014788389205932617 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999947_00000_d_0000002
# Prediction performed in 0.017942190170288086 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000396
# Prediction performed in 0.015712499618530273 seconds.
# Object Density: 16
# *****************************************
# File Name: 9999973_00000_d_0000141
# Prediction performed in 0.02158355712890625 seconds.
# Object Density: 16
# *****************************************
# File Name: 9999973_00000_d_0000005
# Prediction performed in 0.021342754364013672 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999938_00000_d_0000345
# Prediction performed in 0.015341997146606445 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999973_00000_d_0000128
# Prediction performed in 0.0210568904876709 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000007
# Prediction performed in 0.015279531478881836 seconds.
# Object Density: 25
# *****************************************
# File Name: 9999979_00000_d_0000051
# Prediction performed in 0.01798105239868164 seconds.
# Object Density: 23
# *****************************************
# File Name: 9999938_00000_d_0000056
# Prediction performed in 0.015407323837280273 seconds.
# Object Density: 19
# *****************************************
# File Name: 9999973_00000_d_0000049
# Prediction performed in 0.02113175392150879 seconds.
# Object Density: 16
# *****************************************
# File Name: 9999938_00000_d_0000392
# Prediction performed in 0.015396833419799805 seconds.
# Object Density: 7
# *****************************************
# File Name: 9999938_00000_d_0000328
# Prediction performed in 0.01514434814453125 seconds.
# Object Density: 11
# *****************************************
# File Name: 9999952_00000_d_0000066
# Prediction performed in 0.015097379684448242 seconds.
# Object Density: 12
# *****************************************
# File Name: 9999938_00000_d_0000273
# Prediction performed in 0.01641988754272461 seconds.
# Object Density: 37
# *****************************************
# File Name: 9999952_00000_d_0000202
# Prediction performed in 0.015168428421020508 seconds.
# Object Density: 22
# *****************************************
# File Name: 9999996_00000_d_0000013
# Prediction performed in 0.018126487731933594 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000035
# Prediction performed in 0.015404939651489258 seconds.
# Object Density: 15
# *****************************************
# File Name: 9999952_00000_d_0000083
# Prediction performed in 0.015201330184936523 seconds.
# Object Density: 6
# *****************************************
# File Name: 9999963_00000_d_0000068
# Prediction performed in 0.018250465393066406 seconds.
# Object Density: 29
# *****************************************
# File Name: 9999938_00000_d_0000475
# Prediction performed in 0.015512228012084961 seconds.
# Object Density: 29
# *****************************************
# File Name: 9999979_00000_d_0000015
# Prediction performed in 0.017818450927734375 seconds.
# Object Density: 27
# *****************************************
# File Name: 9999938_00000_d_0000259
# Prediction performed in 0.015679121017456055 seconds.
# Object Density: 26
# *****************************************
# File Name: 0000187_00666_d_0000191
# Prediction performed in 0.011154890060424805 seconds.
# Object Density: 15
# *****************************************
# File Name: 9999973_00000_d_0000112
# Prediction performed in 0.021100759506225586 seconds.
# Object Density: 18
# *****************************************
# File Name: 9999963_00000_d_0000070
# Prediction performed in 0.017968416213989258 seconds.
# Object Density: 29
# *****************************************
# File Name: 9999952_00000_d_0000295
# Prediction performed in 0.015686750411987305 seconds.
# Object Density: 18
# *****************************************
# File Name: 9999986_00000_d_0000005
# Prediction performed in 0.017890453338623047 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999952_00000_d_0000096
# Prediction performed in 0.015718936920166016 seconds.
# Object Density: 12
# *****************************************
# File Name: 9999938_00000_d_0000023
# Prediction performed in 0.014862298965454102 seconds.
# Object Density: 5
# *****************************************
# File Name: 0000063_05000_d_0000006
# Prediction performed in 0.011289119720458984 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999938_00000_d_0000072
# Prediction performed in 0.015241146087646484 seconds.
# Object Density: 14
# *****************************************
# File Name: 9999952_00000_d_0000197
# Prediction performed in 0.015080690383911133 seconds.
# Object Density: 25
# *****************************************
# File Name: 9999973_00000_d_0000108
# Prediction performed in 0.021227598190307617 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000431
# Prediction performed in 0.015479087829589844 seconds.
# Object Density: 15
# *****************************************
# File Name: 0000353_06000_d_0000200
# Prediction performed in 0.014760732650756836 seconds.
# Object Density: 20
# *****************************************
# File Name: 9999938_00000_d_0000425
# Prediction performed in 0.0150909423828125 seconds.
# Object Density: 28
# *****************************************
# File Name: 9999938_00000_d_0000248
# Prediction performed in 0.015402078628540039 seconds.
# Object Density: 32
# *****************************************
# File Name: 9999963_00000_d_0000018
# Prediction performed in 0.019062042236328125 seconds.
# Object Density: 26
# *****************************************
# File Name: 9999952_00000_d_0000081
# Prediction performed in 0.015619516372680664 seconds.
# Object Density: 11
# *****************************************
# File Name: 9999938_00000_d_0000323
# Prediction performed in 0.015130043029785156 seconds.
# Object Density: 12
# *****************************************
# File Name: 9999952_00000_d_0000062
# Prediction performed in 0.015152931213378906 seconds.
# Object Density: 9
# Analysis results saved to predicted_outputs.xlsx
