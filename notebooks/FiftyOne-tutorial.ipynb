# %%
# !pip install fiftyone
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fiftyone
#   Downloading fiftyone-1.7.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiofiles in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (23.2.1)
# Collecting argcomplete (from fiftyone)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: async_lru>=2 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (4.12.3)
# Requirement already satisfied: boto3 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (1.37.4)
# Requirement already satisfied: cachetools in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (5.3.2)
# Collecting dacite<1.8.0,>=1.6.0 (from fiftyone)
#   Downloading dacite-1.7.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: dill in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (0.3.7)
# Collecting Deprecated (from fiftyone)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting ftfy (from fiftyone)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting humanize (from fiftyone)
#   Downloading humanize-4.12.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting hypercorn>=0.13.2 (from fiftyone)
#   Downloading hypercorn-0.17.3-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Jinja2>=3 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (3.1.3)
# Collecting kaleido!=0.2.1.post1 (from fiftyone)
#   Downloading kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (3.8.2)
# Collecting mongoengine~=0.29.1 (from fiftyone)
#   Downloading mongoengine-0.29.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting motor~=3.6.0 (from fiftyone)
#   Downloading motor-3.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (1.26.4)
# Requirement already satisfied: packaging in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (23.1)
# Requirement already satisfied: pandas in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (2.2.0)
# Requirement already satisfied: Pillow>=6.2 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (10.2.0)
# Requirement already satisfied: plotly>=4.14 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (6.0.1)
# Collecting pprintpp (from fiftyone)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: psutil in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (5.9.0)
# Collecting pymongo~=4.9.2 (from fiftyone)
#   Downloading pymongo-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytz in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (2023.3.post1)
# Requirement already satisfied: PyYAML in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (6.0.1)
# Requirement already satisfied: regex in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (2023.12.25)
# Collecting retrying (from fiftyone)
#   Downloading retrying-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting rtree (from fiftyone)
#   Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: scikit-learn in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (1.4.0)
# Requirement already satisfied: scikit-image in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (0.24.0)
# Requirement already satisfied: scipy in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (1.12.0)
# Requirement already satisfied: setuptools in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (75.8.2)
# Collecting sseclient-py<2,>=1.7.2 (from fiftyone)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting sse-starlette<1,>=0.10.3 (from fiftyone)
#   Downloading sse_starlette-0.10.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: starlette>=0.24.0 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (0.46.2)
# Collecting strawberry-graphql>=0.262.4 (from fiftyone)
#   Downloading strawberry_graphql-0.275.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting tabulate (from fiftyone)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tqdm in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (4.66.1)
# Requirement already satisfied: xmltodict in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from fiftyone) (0.13.0)
# Collecting universal-analytics-python3<2,>=1.0.1 (from fiftyone)
#   Downloading universal_analytics_python3-1.1.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting pydash (from fiftyone)
#   Downloading pydash-8.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting fiftyone-brain<0.22,>=0.21.2 (from fiftyone)
#   Downloading fiftyone_brain-0.21.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting fiftyone-db<2.0,>=0.4 (from fiftyone)
#   Downloading fiftyone_db-1.3.0.tar.gz (8.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting voxel51-eta<0.15,>=0.14.2 (from fiftyone)
#   Downloading voxel51_eta-0.14.2-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: opencv-python-headless in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from fiftyone) (4.10.0.84)
# Requirement already satisfied: typing_extensions>=4.0.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from async_lru>=2->fiftyone) (4.9.0)
# Requirement already satisfied: exceptiongroup>=1.1.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: h11 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from hypercorn>=0.13.2->fiftyone) (0.14.0)
# Collecting h2>=3.1.0 (from hypercorn>=0.13.2->fiftyone)
#   Downloading h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting priority (from hypercorn>=0.13.2->fiftyone)
#   Downloading priority-2.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting taskgroup (from hypercorn>=0.13.2->fiftyone)
#   Downloading taskgroup-0.2.2-py2.py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tomli in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from hypercorn>=0.13.2->fiftyone) (2.2.1)
# Requirement already satisfied: wsproto>=0.14.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from hypercorn>=0.13.2->fiftyone) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from Jinja2>=3->fiftyone) (2.1.4)
# Collecting choreographer>=1.0.5 (from kaleido!=0.2.1.post1->fiftyone)
#   Downloading choreographer-1.0.9-py3-none-any.whl.metadata (5.6 kB)
# Collecting logistro>=1.0.8 (from kaleido!=0.2.1.post1->fiftyone)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from kaleido!=0.2.1.post1->fiftyone) (3.10.18)
# Requirement already satisfied: narwhals>=1.15.1 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from plotly>=4.14->fiftyone) (1.37.1)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo~=4.9.2->fiftyone)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from starlette>=0.24.0->fiftyone) (4.8.0)
# Collecting graphql-core<3.4.0,>=3.2.0 (from strawberry-graphql>=0.262.4->fiftyone)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil<3.0,>=2.7 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from strawberry-graphql>=0.262.4->fiftyone) (2.8.2)
# Requirement already satisfied: httpx>=0.10.0 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from universal-analytics-python3<2,>=1.0.1->fiftyone) (0.28.1)
# Collecting future (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: glob2 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (0.7)
# Collecting jsonlines (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting py7zr (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading py7zr-1.0.0-py3-none-any.whl.metadata (17 kB)
# Collecting rarfile (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: requests in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.31.0)
# Requirement already satisfied: six in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (1.16.0)
# Requirement already satisfied: sortedcontainers in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.4.0)
# Collecting tzlocal (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: urllib3 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from voxel51-eta<0.15,>=0.14.2->fiftyone) (2.4.0)
# Requirement already satisfied: soupsieve>1.2 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from beautifulsoup4->fiftyone) (2.5)
# Requirement already satisfied: botocore<1.38.0,>=1.37.4 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from boto3->fiftyone) (1.37.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from boto3->fiftyone) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from boto3->fiftyone) (0.11.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from Deprecated->fiftyone) (1.17.2)
# Requirement already satisfied: wcwidth in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from ftfy->fiftyone) (0.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from matplotlib->fiftyone) (6.1.1)
# Requirement already satisfied: tzdata>=2022.7 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from pandas->fiftyone) (2023.4)
# Requirement already satisfied: networkx>=2.8 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from scikit-image->fiftyone) (3.0)
# Requirement already satisfied: imageio>=2.33 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from scikit-image->fiftyone) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from scikit-image->fiftyone) (2024.2.12)
# Requirement already satisfied: lazy-loader>=0.4 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from scikit-image->fiftyone) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from scikit-learn->fiftyone) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from scikit-learn->fiftyone) (3.2.0)
# Requirement already satisfied: idna>=2.8 in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette>=0.24.0->fiftyone) (1.3.0)
# Collecting urllib3 (from voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.5->kaleido!=0.2.1.post1->fiftyone)
#   Downloading simplejson-3.20.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting hyperframe<7,>=6.1 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2>=3.1.0->hypercorn>=0.13.2->fiftyone)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages (from httpx>=0.10.0->universal-analytics-python3<2,>=1.0.1->fiftyone) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->fiftyone) (3.17.0)
# Requirement already satisfied: attrs>=19.2.0 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from jsonlines->voxel51-eta<0.15,>=0.14.2->fiftyone) (23.2.0)
# Collecting texttable (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting pycryptodomex>=3.20.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting brotli>=1.1.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading Brotli-1.1.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (5.5 kB)
# Collecting pyzstd>=0.16.1 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pyzstd-0.17.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting pyppmd<1.3.0,>=1.1.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pyppmd-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting pybcj<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading pybcj-1.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting multivolumefile>=0.2.3 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting inflate64<1.1.0,>=1.0.0 (from py7zr->voxel51-eta<0.15,>=0.14.2->fiftyone)
#   Downloading inflate64-1.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mmfs1/cm/shared/apps_local/python/shared_envs/torch11.8/lib/python3.9/site-packages (from requests->voxel51-eta<0.15,>=0.14.2->fiftyone) (3.3.2)
# Collecting typing_extensions>=4.0.0 (from async_lru>=2->fiftyone)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Downloading fiftyone-1.7.0-py3-none-any.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 65.4 MB/s eta 0:00:0000:010:01
# Downloading dacite-1.7.0-py3-none-any.whl (12 kB)
# Downloading fiftyone_brain-0.21.2-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 21.6 MB/s eta 0:00:00
# Downloading hypercorn-0.17.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 14.9 MB/s eta 0:00:00
# Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 9.8 MB/s eta 0:00:00
# Downloading mongoengine-0.29.1-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 8.1 MB/s eta 0:00:00
# Downloading motor-3.6.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 18.2 MB/s eta 0:00:00
# Downloading pymongo-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.2 MB/s eta 0:00:00
# Downloading sse_starlette-0.10.3-py3-none-any.whl (8.0 kB)
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading strawberry_graphql-0.275.5-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.3/306.3 kB 52.8 MB/s eta 0:00:00
# Downloading universal_analytics_python3-1.1.1-py3-none-any.whl (10 kB)
# Downloading voxel51_eta-0.14.2-py2.py3-none-any.whl (943 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 943.0/943.0 kB 59.9 MB/s eta 0:00:00
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 10.5 MB/s eta 0:00:00
# Downloading humanize-4.12.3-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 23.1 MB/s eta 0:00:00
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pydash-8.0.5-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 23.4 MB/s eta 0:00:00
# Downloading retrying-1.4.0-py3-none-any.whl (11 kB)
# Downloading rtree-1.4.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 61.8 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading choreographer-1.0.9-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 11.2 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 14.2 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 44.6 MB/s eta 0:00:00
# Downloading h2-4.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 65.5 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading priority-2.0.0-py3-none-any.whl (8.9 kB)
# Downloading py7zr-1.0.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 19.1 MB/s eta 0:00:00
# Downloading rarfile-4.2-py3-none-any.whl (29 kB)
# Downloading taskgroup-0.2.2-py2.py3-none-any.whl (14 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 8.0 MB/s eta 0:00:00
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading Brotli-1.1.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 34.2 MB/s eta 0:00:00:00:01
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading inflate64-1.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 7.2 MB/s eta 0:00:00
# Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Downloading pybcj-1.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 12.6 MB/s eta 0:00:00
# Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.1 MB/s eta 0:00:00:00:01
# Downloading pyppmd-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 32.4 MB/s eta 0:00:00
# Downloading pyzstd-0.17.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 65.1 MB/s eta 0:00:00
# Downloading simplejson-3.20.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 9.0 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fiftyone-db
#   Building wheel for fiftyone-db (pyproject.toml) ... done
#   Created wheel for fiftyone-db: filename=fiftyone_db-1.3.0-py3-none-manylinux1_x86_64.whl size=6062 sha256=64ed971352dea546c0a334f4053b6e55a95d7c8765d73a2adfd5812b60caf7a9
#   Stored in directory: /mmfs1/home/dsu.local/bshakya/.cache/pip/wheels/d2/33/a1/a7a7707b120ea77da478d2dfef6f94e243820b56b52c5d071f
# Successfully built fiftyone-db
# Installing collected packages: texttable, sseclient-py, pprintpp, brotli, urllib3, tzlocal, typing_extensions, tabulate, simplejson, rtree, retrying, rarfile, pyppmd, pycryptodomex, pybcj, priority, multivolumefile, logistro, jsonlines, inflate64, hyperframe, humanize, hpack, future, ftfy, fiftyone-db, dnspython, Deprecated, dacite, argcomplete, taskgroup, pyzstd, pymongo, pydash, h2, graphql-core, choreographer, strawberry-graphql, py7zr, motor, mongoengine, kaleido, hypercorn, fiftyone-brain, voxel51-eta, universal-analytics-python3, sse-starlette, fiftyone
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 4.44.1 requires urllib3~=2.0, but you have urllib3 1.26.20 which is incompatible.
# Successfully installed Deprecated-1.2.18 argcomplete-3.6.2 brotli-1.1.0 choreographer-1.0.9 dacite-1.7.0 dnspython-2.7.0 fiftyone-1.7.0 fiftyone-brain-0.21.2 fiftyone-db-1.3.0 ftfy-6.3.1 future-1.0.0 graphql-core-3.2.6 h2-4.2.0 hpack-4.1.0 humanize-4.12.3 hypercorn-0.17.3 hyperframe-6.1.0 inflate64-1.0.3 jsonlines-4.0.0 kaleido-1.0.0 logistro-1.1.0 mongoengine-0.29.1 motor-3.6.1 multivolumefile-0.2.3 pprintpp-0.4.0 priority-2.0.0 py7zr-1.0.0 pybcj-1.0.6 pycryptodomex-3.23.0 pydash-8.0.5 pymongo-4.9.2 pyppmd-1.2.0 pyzstd-0.17.0 rarfile-4.2 retrying-1.4.0 rtree-1.4.0 simplejson-3.20.1 sse-starlette-0.10.3 sseclient-py-1.8.0 strawberry-graphql-0.275.5 tabulate-0.9.0 taskgroup-0.2.2 texttable-1.7.0 typing_extensions-4.14.0 tzlocal-5.3.1 universal-analytics-python3-1.1.1 urllib3-1.26.20 voxel51-eta-0.14.2

# %%
import fiftyone as fo

# %%
import fiftyone.zoo as foz

dataset = foz.load_zoo_dataset("quickstart")
# Out:
# Downloading dataset to '/home/dsu.local/bshakya/fiftyone/quickstart'
# Downloading dataset...
#  100% |████|  187.5Mb/187.5Mb [416.0ms elapsed, 0s remaining, 450.9Mb/s]
# Extracting dataset...
# Parsing dataset metadata
# Found 200 samples
# Dataset info written to '/home/dsu.local/bshakya/fiftyone/quickstart/info.json'
# ---------------------------------------------------------------------------
# ServiceExecutableNotFound                 Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/odm/database.py:204, in establish_db_conn(config)
#     203 try:
# --> 204     _db_service = fos.DatabaseService()
#     205     port = _db_service.port
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/service.py:81, in Service.__init__(self)
#      80 if not self._disabled:
# ---> 81     self.start()
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/service.py:210, in MultiClientService.start(self)
#     208         logger.warning("%s did not respond", desc)
# --> 210 super().start()
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/service.py:119, in Service.start(self)
#     114 # use psutil's Popen wrapper because its wait() more reliably waits
#     115 # for the process to exit on Windows
#     116 self.child = psutil.Popen(
#     117     [sys.executable, service_main_path]
#     118     + self._service_args
# --> 119     + self.command,
#     120     cwd=self.working_dir,
#     121     stdin=subprocess.PIPE,
#     122     env={**os.environ, "FIFTYONE_DISABLE_SERVICES": "1", **self.env},
#     123 )
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/service.py:239, in DatabaseService.command(self)
#     236 log_path = os.path.join(database_dir, "log", "mongo.log")
#     238 args = [
# --> 239     DatabaseService.find_mongod(),
#     240     "--dbpath",
#     241     database_dir,
#     242     "--logpath",
#     243     log_path,
#     244     "--port",
#     245     "0",
#     246 ]
#     247 if not sys.platform.startswith("win"):
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/service.py:287, in DatabaseService.find_mongod()
#     286 if not os.path.isfile(mongod):
# --> 287     raise ServiceExecutableNotFound("Could not find `mongod`")
#     289 if not os.access(mongod, os.X_OK):
#
# ServiceExecutableNotFound: Could not find `mongod`
#
# During handling of the above exception, another exception occurred:
#
# FiftyOneConfigError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import fiftyone.zoo as foz
# ----> 3 dataset = foz.load_zoo_dataset("quickstart")
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/zoo/datasets/__init__.py:415, in load_zoo_dataset(name_or_url, split, splits, label_field, dataset_name, download_if_necessary, drop_existing_dataset, persistent, overwrite, cleanup, progress, **kwargs)
#     412     if "max_samples" in importer_kwargs:
#     413         dataset_name += "-%s" % importer_kwargs["max_samples"]
# --> 415 if fo.dataset_exists(dataset_name):
#     416     if not drop_existing_dataset:
#     417         logger.info(
#     418             "Loading existing dataset '%s'. To reload from disk, either "
#     419             "delete the existing dataset or provide a custom "
#     420             "`dataset_name` to use",
#     421             dataset_name,
#     422         )
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/dataset.py:104, in dataset_exists(name)
#      95 def dataset_exists(name):
#      96     """Checks if the dataset exists.
#      97
#      98     Args:
#    (...)
#     102         True/False
#     103     """
# --> 104     conn = foo.get_db_conn()
#     105     return bool(list(conn.datasets.find({"name": name}, {"_id": 1}).limit(1)))
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/odm/database.py:470, in get_db_conn()
#     464 def get_db_conn():
#     465     """Returns a connection to the database.
#     466
#     467     Returns:
#     468         a ``pymongo.database.Database``
#     469     """
# --> 470     _connect()
#     471     db = _client[fo.config.database_name]
#     472     return _apply_options(db)
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/odm/database.py:246, in _connect()
#     243 if _client is None:
#     244     global _connection_kwargs
# --> 246     establish_db_conn(fo.config)
#
# File ~/.local/lib/python3.9/site-packages/fiftyone/core/odm/database.py:210, in establish_db_conn(config)
#     207         os.environ["FIFTYONE_PRIVATE_DATABASE_PORT"] = str(port)
#     209     except fos.ServiceExecutableNotFound:
# --> 210         raise FiftyOneConfigError(
#     211             "MongoDB could not be installed on your system. Please "
#     212             "define a `database_uri` in your "
#     213             "`fiftyone.core.config.FiftyOneConfig` to connect to your"
#     214             "own MongoDB instance or cluster "
#     215         )
#     217 _client = pymongo.MongoClient(
#     218     **_connection_kwargs, appname=foc.DATABASE_APPNAME
#     219 )
#     220 _validate_db_version(config, _client)
#
# FiftyOneConfigError: MongoDB could not be installed on your system. Please define a `database_uri` in your `fiftyone.core.config.FiftyOneConfig` to connect to yourown MongoDB instance or cluster

# %%
print(dataset)
