# %%
pwd
# Out:
# '/mmfs1/scratch/dsu.local/bshakya/scratch/bshakya/YOLOv8'

# %%
# !pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.3.11
# Summary: Ultralytics YOLO for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page:
# Author:
# Author-email: Glenn Jocher <glenn.jocher@ultralytics.com>, Jing Qiu <jing.qiu@ultralytics.com>
# License: AGPL-3.0
# Location: /mmfs1/home/dsu.local/bshakya/.local/lib/python3.9/site-packages
# Requires: matplotlib, numpy, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, torch, torchvision, tqdm, ultralytics-thop
# Required-by: yolov5

# %%
# !pip install -U ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ultralytics-8.3.91-py3-none-any.whl.metadata (35 kB)
# ...
# Using cached ultralytics-8.3.91-py3-none-any.whl (949 kB)
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.11
#     Uninstalling ultralytics-8.3.11:
#       Successfully uninstalled ultralytics-8.3.11
# ...

# %%
# !pip install ultralytics==8.3.11
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ultralytics-8.3.11-py3-none-any.whl.metadata (34 kB)
# ...
# Using cached ultralytics-8.3.11-py3-none-any.whl (882 kB)
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.91
#     Uninstalling ultralytics-8.3.91:
#       Successfully uninstalled ultralytics-8.3.91
# ...

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU (test-dev dataset)
benchmark(model="yolov10n.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
#benchmark(model="../yolov10/yolov10/runs/detect/train3/weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.7/430.3 GB disk)
#
# Benchmarks complete for yolov10n.pt on VisDrone_bk.yaml at imgsz=640 (47.06s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅       10.9               0.0140                    6.49  154.18
# 1             TorchScript       ✅       11.2               0.0139                    2.86  349.69
# 2                    ONNX       ✅        9.0               0.0139                    5.97  167.63
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU (test-dev dataset)
benchmark(model="../yolov10/yolov10/runs/detect/train3/weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.7/430.3 GB disk)
#
# Benchmarks complete for last.pt on VisDrone_bk.yaml at imgsz=640 (89.61s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.5               0.1449                    6.54  152.88
# 1             TorchScript       ✅       10.9               0.1452                    2.95  338.63
# 2                    ONNX       ✅        8.9               0.1452                    5.42  184.60
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
ls ../YOLOv11/weights/last.pt
# Out:
# ../YOLOv11/weights/last.pt

# %%
from ultralytics.utils.benchmarks import benchmark
#yolov10/detect/train7
# Benchmark on GPU (test-dev dataset)
benchmark(model="../yolov10/yolov10/runs/detect/train7/weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.7/430.3 GB disk)
#
# Benchmarks complete for last.pt on DOTAv1.5.yaml at imgsz=640 (144.80s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.5               0.1957                    7.19  139.09
# 1             TorchScript       ✅       11.0               0.1980                    3.12  320.96
# 2                    ONNX       ✅        8.9               0.1980                    5.63  177.57
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#yolo10/detect/train43 --> YOLOv8
# Benchmark on GPU (test-dev dataset)
benchmark(model="weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
#benchmark(model="weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 26.7/430.3 GB disk)
#
# Benchmarks complete for last.pt on VisDrone_bk.yaml at imgsz=640 (24.61s)
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)   FPS
# 0                 PyTorch       ❎        5.9                None                   None  None
# 1             TorchScript       ❎       11.9                None                   None  None
# 2                    ONNX       ❎       11.7                None                   None  None
# 3                OpenVINO       ❌        0.0                None                   None  None
# 4                TensorRT       ❌        0.0                None                   None  None
# 5                  CoreML       ❌        0.0                None                   None  None
# 6   TensorFlow SavedModel       ❌        0.0                None                   None  None
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#yolo10/detect/train43 --> YOLOv8
# Benchmark on GPU (test-dev dataset)
#benchmark(model="yolov10n.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
benchmark(model="weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.7/430.3 GB disk)
#
# Benchmarks complete for last.pt on DOTAv1.5.yaml at imgsz=640 (21.08s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.9               0.2101                    4.70  212.94
# 1             TorchScript       ✅       11.9               0.2096                    2.07  484.16
# 2                    ONNX       ✅       11.7               0.2095                    5.92  169.02
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#yolo10/detect/train43 --> YOLOv8
# Benchmark on GPU (test-dev dataset)
benchmark(model="yolov10n.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
#benchmark(model="weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.5/430.3 GB disk)
#
# Benchmarks complete for yolov10n.pt on VisDrone_bk.yaml at imgsz=640 (87.64s)
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)   FPS
# 0                 PyTorch       ❎       10.9                None                   None  None
# 1             TorchScript       ❎       11.2                None                   None  None
# 2                    ONNX       ❎        9.0                None                   None  None
# 3                OpenVINO       ❌        0.0                None                   None  None
# 4                TensorRT       ❌        0.0                None                   None  None
# 5                  CoreML       ❌        0.0                None                   None  None
# 6   TensorFlow SavedModel       ❌        0.0                None                   None  None
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> DOTA1.5
# Benchmark on GPU (test dataset)
benchmark(model="../YOLOv11/runs/detect/train31/weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.5/430.3 GB disk)
#
# Benchmarks complete for last.pt on DOTAv1.5.yaml at imgsz=640 (153.28s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2                  0.0                    5.75  173.85
# 1             TorchScript       ✅       10.4                  0.0                    2.78  359.36
# 2                    ONNX       ✅       10.1                  0.0                    5.56  179.79
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> DOTA1.5
# Benchmark on GPU (val dataset)
benchmark(model="../YOLOv11/runs/detect/train31/weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 25.7/430.3 GB disk)
#
# Benchmarks complete for last.pt on DOTAv1.5.yaml at imgsz=640 (65.66s)
#                    Format Status❔  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2               0.2061                    5.83  171.36
# 1             TorchScript       ✅       10.4               0.2065                    2.95  338.47
# 2                    ONNX       ✅       10.1               0.2065                    6.21  161.04
# 3                OpenVINO       ❌        0.0                  NaN                     NaN     NaN
# 4                TensorRT       ❌        0.0                  NaN                     NaN     NaN
# 5                  CoreML       ❌        0.0                  NaN                     NaN     NaN
# 6   TensorFlow SavedModel       ❌        0.0                  NaN                     NaN     NaN
# ...

# %%
pwd
# Out:
# '/mmfs1/scratch/dsu.local/bshakya/scratch/bshakya/YOLOv8'

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone
# Benchmark on GPU (test-dev dataset)
benchmark(model="../YOLOv11/weights/VisDrone/best.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 26.7/430.3 GB disk)
#
# Benchmarks complete for best.pt on VisDrone_bk.yaml at imgsz=640 (11.30s)
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)   FPS
# 0                 PyTorch       ❎        5.2                None                   None  None
# 1             TorchScript       ❎       10.4                None                   None  None
# 2                    ONNX       ❎       10.1                None                   None  None
# 3                OpenVINO       ❌        0.0                None                   None  None
# 4                TensorRT       ❌        0.0                None                   None  None
# 5                  CoreML       ❌        0.0                None                   None  None
# 6   TensorFlow SavedModel       ❌        0.0                None                   None  None
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone
# Benchmark on GPU (test-dev dataset)
benchmark(model="../YOLOv11/weights/VisDrone/best.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 from ultralytics.utils.benchmarks import benchmark
#       2 #YOLOv11 --> VisDrone
#       3 # Benchmark on GPU (test-dev dataset)
# ----> 4 benchmark(model="../YOLOv11/weights/VisDrone/best.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0, batch=16)
#
# TypeError: benchmark() got an unexpected keyword argument 'batch'

# %%
from ultralytics.utils.benchmarks import benchmark
#from ultralytics import YOLO
import torch
#YOLOv11 --> VisDrone
# Benchmark on GPU (test-dev dataset)
#model = YOLO()
#model.load_state_dict(torch.load("../YOLOX-CustomTraining/YOLOX/YOLOX_outputs/yolo_voc_s_50/yolox_voc_s/latest_ckpt.pth"))
#model.val()
benchmark(model="../tph-yolov5/runs/train/v5l-xs-50-tph/weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)

# %%
ls ../yolov9/runs/train/exp/weights/last.pt
# Out:
# ../yolov9/runs/train/exp/weights/last.pt

# %% [markdown]
# **YOLOv8n - 150 epochs**

# %%
from ultralytics.utils.benchmarks import benchmark
#yolo10/detect/train43 --> YOLOv8
# Benchmark on GPU (test-dev dataset)
benchmark(model="runs/detect/train4/weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
#benchmark(model="weights/last.pt", data="DOTAv1.5.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train4/weights/last.pt on VisDrone_bk.yaml at imgsz=640 (93.68s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1547                   4.05  246.56
# 1             TorchScript       ✅       11.9              0.1552                   2.45  408.48
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
ls runs/detect/train20/weights/last.pt
# Out:
# runs/detect/train20/weights/last.pt

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8n --> VisDrone --> 50 epochs --> Mixed dataset  --> Test: 500 mix images
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train23/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.9/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train23/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (55.78s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1373                   4.63  215.86
# 1             TorchScript       ✅       11.9              0.1385                   2.34  426.61
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (test-dev dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.9/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (13.79s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0                0.15                   4.45  224.43
# 1             TorchScript       ✅       11.9              0.1496                   2.39  417.94
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (test-dev dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (29.03s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1542                   4.48  223.11
# 1             TorchScript       ✅       11.9              0.1533                   2.85  351.08
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (15.07s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1419                   4.99   200.3
# 1             TorchScript       ✅       11.9              0.1481                   2.66  376.07
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=128, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=128 (14.71s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1492                    5.2  192.31
# 1             TorchScript       ✅       11.8              0.1715                   2.92  341.94
# 2                    ONNX       ❎       11.5                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=64, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=64 (14.56s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1047                   5.35  186.82
# 1             TorchScript       ✅       11.8              0.1317                    3.0   333.2
# 2                    ONNX       ❎       11.5                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train20/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=128, lr0=0.0005, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train20/weights/last.pt on VisDrone-mixed.yaml at imgsz=128 (14.56s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1492                   5.32  187.92
# 1             TorchScript       ✅       11.8              0.1715                   3.04  328.97
# 2                    ONNX       ❎       11.5                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv8 --> VisDrone --> 150 epochs --> Full dataset
# Benchmark on GPU (test dataset - mix of 500 images)
benchmark(model="runs/detect/train4/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.9/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train4/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (14.23s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        6.0              0.1514                   4.63   216.1
# 1             TorchScript       ✅       11.9              0.1524                   2.54  393.03
# 2                    ONNX       ❎       11.7                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %% [markdown]
# **YOLOv11n - 150 epochs**

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Full dataset
# Benchmark on GPU (test-dev dataset)
benchmark(model="../YOLOv11/runs/detect/train38/weights/last.pt", data="VisDrone_bk.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for ../YOLOv11/runs/detect/train38/weights/last.pt on VisDrone_bk.yaml at imgsz=640 (36.16s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.1575                   6.08  164.41
# 1             TorchScript       ✅       10.4              0.1571                   3.41  293.35
# 2                    ONNX       ❎       10.1                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (test-dev dataset)
benchmark(model="runs/detect/train21/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train21/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (36.98s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.1548                   6.41  155.99
# 1             TorchScript       ✅       10.4              0.1546                   3.64  274.58
# 2                    ONNX       ❎       10.1                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train21/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train21/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (19.48s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.1422                   7.29  137.17
# 1             TorchScript       ✅       10.4              0.1468                   3.61  276.61
# 2                    ONNX       ❎       10.1                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Sliced dataset)
benchmark(model="runs/detect/train21/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=128, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.8/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train21/weights/last.pt on VisDrone-mixed.yaml at imgsz=128 (19.64s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.1421                   6.94  143.98
# 1             TorchScript       ✅       10.3               0.157                   3.88  257.81
# 2                    ONNX       ❎        9.9                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Mixed dataset
# Benchmark on GPU (Test: Mix 500 dataset)
benchmark(model="runs/detect/train21/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.9/430.3 GB disk)
#
# Benchmarks complete for runs/detect/train21/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (19.24s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2               0.152                   6.33  157.93
# 1             TorchScript       ✅       10.4              0.1519                   3.68  271.98
# 2                    ONNX       ❎       10.1                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
#YOLOv11 --> VisDrone --> 150 epochs --> Full dataset
# Benchmark on GPU (Test: Mix 500 dataset)
benchmark(model="../YOLOv11/runs/detect/train38/weights/last.pt", data="VisDrone-mixed.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete ✅ (48 CPUs, 503.3 GB RAM, 37.9/430.3 GB disk)
#
# Benchmarks complete for ../YOLOv11/runs/detect/train38/weights/last.pt on VisDrone-mixed.yaml at imgsz=640 (18.70s)
# Benchmarks legend:  - ✅ Success  - ❎ Export passed but validation failed  - ❌️ Export failed
#                    Format Status❔  Size (MB) metrics/mAP50-95(B) Inference time (ms/im)     FPS
# 0                 PyTorch       ✅        5.2              0.1541                   6.29  158.91
# 1             TorchScript       ✅       10.4              0.1531                   3.67  272.52
# 2                    ONNX       ❎       10.1                   -                      -       -
# 3                OpenVINO       ❌        0.0                   -                      -       -
# 4                TensorRT       ❌        0.0                   -                      -       -
# 5                  CoreML       ❌        0.0                   -                      -       -
# ...

# %% [markdown]
# **Remarks**
#
# 1. Install `pip install ultralytics==8.2.91` for fixing v10DetectLoss module rename for YOLOv10 --> restart kernel
# 2. Intall `pip install ultralytics==8.3.11` for fixing AttributeError: Can't get attribute 'C3k2' on <module 'ultralytics.nn.modules.block' for YOLOv11 --> restart kernel
